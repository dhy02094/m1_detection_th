# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %%
path1 = '/Users/kimtaehyeong/Desktop/01_앞면_윗니 오른쪽'
os.chdir(path1)
files1 = os.listdir(path1) # 파일 폴더명 반환

data = []
for file in files1:
    f = cv2.imread(file)
    data.append(f)

# %%
len(data)
# Out:
# 2687

# %% [markdown]
# # Train, Valid, Test = 5:3:2 로 나누기

# %%
# train, test 나누기
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, 
                               test_size=0.2,
                               shuffle=True,
                               random_state=42)

# %%
print(len(train))
print(len(test))
# Out:
# 2149
# 538

# %%
train, valid = train_test_split(train,
                               test_size = 3/8,
                               shuffle = True,
                               random_state =42)

# %%
print('Train : ', len(train))
print('Valid : ',len(valid))
print('Test : ',len(test))
# Out:
# Train :  1343
# Valid :  806
# Test :  538

# %%
# Train outlier data load
path1 = '/Users/kimtaehyeong/Downloads/outlier/train outlier'
os.chdir(path1)
files1 = os.listdir(path1)

for file in files1:
    f = cv2.imread(file)
    train.append(f)

# %%
path2 = '/Users/kimtaehyeong/Downloads/outlier/test outlier'
os.chdir(path2)
files2 = os.listdir(path2)

for file in files2:
    f = cv2.imread(file)
    test.append(f)

# %%
path3 = '/Users/kimtaehyeong/Downloads/outlier/valid outlier'
os.chdir(path3)
files3 = os.listdir(path3)

for file in files3:
    f = cv2.imread(file)
    valid.append(f)

# %%
print('Train: ', len(train))
print('Valid: ', len(valid))
print('Test: ', len(test))
# Out:
# Train:  1358
# Valid:  821
# Test:  552

# %%
def train_visual(data_set) :
    plt.figure(figsize = (10,5))
    
    for i in range(1, 10+1) :
        plt.subplot(2, 5, i)
        plt.imshow(cv2.cvtColor(data_set[i], cv2.COLOR_BGR2RGB))
        plt.title(f'normal image {i} ' )
        plt.axis('off')
    
    # visualize outler in data set
    plt.figure(figsize = (10,7))
    for i in range(1, 15+1) :
        plt.subplot(3,5,i)
        plt.imshow(cv2.cvtColor(data_set[-i], cv2.COLOR_BGR2RGB))
        plt.title(f'outlier image {i} ')
        plt.axis('off')
        
    plt.show()

# %%
def valid_visual(data_set) :
    plt.figure(figsize = (10,5))
    
    for i in range(1, 10+1) :
        plt.subplot(2, 5, i)
        plt.imshow(cv2.cvtColor(data_set[i], cv2.COLOR_BGR2RGB))
        plt.title(f'normal image {i} ' )
        plt.axis('off')
    
    # visualize outler in data set
    plt.figure(figsize = (10,7))
    for i in range(1, 15+1) :
        plt.subplot(4,4,i)
        plt.imshow(cv2.cvtColor(data_set[-i], cv2.COLOR_BGR2RGB))
        plt.title(f'outlier image {i} ')
        plt.axis('off')
        
    plt.show()

# %%
def test_visual(data_set) :
    plt.figure(figsize = (10,5))
    
    for i in range(1, 10+1) :
        plt.subplot(2, 5, i)
        plt.imshow(cv2.cvtColor(data_set[i], cv2.COLOR_BGR2RGB))
        plt.title(f'normal image {i} ' )
        plt.axis('off')
    
    # visualize outler in data set
    plt.figure(figsize = (10,7))
    for i in range(1, 14+1) :
        plt.subplot(4,4,i)
        plt.imshow(cv2.cvtColor(data_set[-i], cv2.COLOR_BGR2RGB))
        plt.title(f'outlier image {i} ')
        plt.axis('off')
        
    plt.show()

# %%
train_visual(train)

# %%
valid_visual(valid)

# %%
test_visual(test)

# %%
train2 = train.copy()
valid2 = valid.copy()
test2 = test.copy()

# %% [markdown]
# # 이미지 전처리

# %%
# image resize
def image_resize(data_set, n_pixel):
    # create empty list
    resized_list = []
    # resize to n pixel 
    for i in range(len(data_set)):
        resized = cv2.resize(data_set[i], dsize=(n_pixel,n_pixel), interpolation=cv2.INTER_CUBIC)
        resized_list.append(resized)
        
    return resized_list

# %%
train = image_resize(train, 224)
valid = image_resize(valid, 224)
test = image_resize(test, 224)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.models import Model
from keras import models
from keras.applications.vgg16 import VGG16
from keras.layers import GlobalAveragePooling2D
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input 
import numpy as np
from numpy import expand_dims
np.random.seed(42)
tf.random.set_seed(42)
from matplotlib import pyplot

# %%
model = VGG16(weights='imagenet')
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 피쳐맵 뽑기

# %%
# 레이어 설정
layers = [2,5,9,13,17]
# 출력값 
outputs = [model.layers[i].output for i in layers]
# 모델 재설정
model = Model(inputs=model.inputs, outputs=outputs)

# feature map 시각화 함수
def fmap_visualize(image):
    img = expand_dims(image, axis=0) # expand dimension
    img = preprocess_input(img) # RGB -> BGR and 0 centered
    
    feature_maps = model.predict(img)
    
    square = 8
    for fmap in feature_maps:
        ix=1
        plt.figure(figsize=(10,10))
        for _ in range(square):
            for _ in range(square):
                ax = pyplot.subplot(square,square,ix)
                ax.set_xticks([])
                ax.set_yticks([])
                pyplot.imshow(fmap[0,:,:,ix-1])
                ix += 1
        pyplot.show()

# %%
fmap_visualize(train[52])
# Out:
# 2021-11-09 10:49:02.231805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# # GAP

# %% [markdown]
# https://github.com/dhy02094/STUDY_TH/blob/master/DL%20study/GAP(global%20average%20pooling).ipynb

# %%
base_model = Model(inputs=model.inputs, outputs=model.layers[9].output)
base_model.summary()

add_model = models.Sequential()
add_model.add(base_model)
add_model.add(GlobalAveragePooling2D())

add_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# =================================================================
# Total params: 1,735,488
# Trainable params: 1,735,488
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_3 (Functional)         (None, 56, 56, 256)       1735488
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# =================================================================
# Total params: 1,735,488
# Trainable params: 1,735,488
# Non-trainable params: 0
# _________________________________________________________________

# %%
def create_fmap(data_set):
    fmap_list = []
    for i in tqdm(range(len(data_set))):
        img2 = data_set[i]
        img2 = expand_dims(img2, axis=0)
        img2 = preprocess_input(img2)
        
        fmap2 = add_model.predict(img2)
        fmap_list.append(fmap2)
    return fmap_list

# %%
train_fmap = create_fmap(train)
# Out:
#   0%|                                                  | 0/1358 [00:00<?, ?it/s]2021-11-09 10:49:07.130631: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 100%|███████████████████████████████████████| 1358/1358 [00:42<00:00, 32.13it/s]

# %%
valid_fmap = create_fmap(valid)
# Out:
# 100%|█████████████████████████████████████████| 821/821 [00:25<00:00, 32.80it/s]

# %%
test_fmap = create_fmap(test)
# Out:
# 100%|█████████████████████████████████████████| 552/552 [00:16<00:00, 32.68it/s]

# %%
train = np.array(train_fmap)
valid = np.array(valid_fmap)
test = np.array(test_fmap)

# %%
print(train.shape)
print(valid.shape)
print(test.shape)
# Out:
# (1358, 1, 256)
# (821, 1, 256)
# (552, 1, 256)

# %%
train2d = train.reshape(train.shape[0],-1)
valid2d = valid.reshape(valid.shape[0], -1)
test2d = test.reshape(test.shape[0],-1)

# %%
print(train2d.shape)
# Out:
# (1358, 256)

# %%
# 다양한 하이퍼파라미터 조합으로 성능 비교
estimator_values = [50,60,70,80,90,100,200,300,500]
sample_values = ['auto',10,30,50,100,200,300,500]
feature_values = [3,5,7,8,9,10,15,20,30]

# isolation forest modeling
from sklearn.ensemble import IsolationForest

predictions = []

for estimator in tqdm(estimator_values):
    for sample in sample_values:
        for feature in feature_values:
            iforest = IsolationForest(n_estimators=estimator, # number of itree
                                      max_samples=sample,     # number of sample
                                      max_features=feature,   # number of feature
                                      contamination=0.005,     # proportion of outliers in train set
                                      random_state=42)
            iforest.fit(train2d)
            # valid data로 predict
            pred = iforest.predict(valid2d)
            predictions.append(pred)
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [01:46<00:00, 11.78s/it]

# %%
# 조합별 모델링 결과 보기
import pandas as pd
combi_result = pd.DataFrame(predictions).T

# %%
# make name of each columns
estimators_str = [str(estimator) for estimator in estimator_values]
samples_str = [str(sample) for sample in sample_values]
features_str = [str(feature) for feature in feature_values]

naming = []

for e in estimators_str:
    for s in samples_str:
        for f in features_str:
            name = e + '_' + s + '_' + f
            naming.append(name)
            
combi_result.columns = naming

# %%
# The outlier of train set is 6
outlier_len = 15

# normal, outlier labeling
combi_result['label_val'] = 0
combi_result.iloc[:len(combi_result)-outlier_len,-1] = 1
combi_result.iloc[len(combi_result)-outlier_len:,-1] = -1

# %%
# 1순위는 이상치를 모두 분류해내는 것
# 올바르게 분류하지 못한 각 파라미터 조합의 로우에 페널티 부여
penalty = 30

for col in combi_result.columns[:-1]:
    
    each_col = combi_result[col][-outlier_len:]
    label_col = combi_result['label_val'][-outlier_len:]
    
    # 각 파라미터 조합의 값 리스트와 label_val의 값 리스트가 다를 경우
    if list(each_col)!=list(label_col):
        for i in each_col.index:
            # 분류 결괏값이 1인 경우 페널티 부여
            if each_col[i]!=-1:
                each_col[i] = each_col[i] * penalty
            # 변경사항 원본 데이터에 적용
            combi_result[col][-outlier_len] = each_col
                
combi_result.tail(15)
# Out:
#      50_auto_3  50_auto_5  50_auto_7  50_auto_8  50_auto_9  50_auto_10  \
# 806         30         30         30         30         30          30
# 807         30         30         30         30         30          30
# 808         30         30         30         30         30          30
# 809         30         30         30         30         30          30
# 810         30         30         30         30         30          30
# 811         30         30         30         30         30          30
# 812         -1         -1         -1         -1         -1          -1
# 813         30         30         30         30         30          30
# 814         30         30         30         30         30          30
# 815         30         30         30         30         30          30
# 816         30         30         30         30         30          30
# 817         -1         -1         -1         -1         -1          -1
# 818         30         30         -1         30         30          -1
# 819         30         30         30         30         30          30
# 820         30         -1         -1         -1         -1          -1
#
#      50_auto_15  50_auto_20  50_auto_30  50_10_3  ...  500_500_3  500_500_5  \
# 806          30          30          30       30  ...         30         30
# 807          30          30          30       30  ...         30         30
# 808          30          30          30       30  ...         30         30
# 809          -1          -1          30       30  ...         30         30
# 810          30          30          30       30  ...         30         30
# 811          30          30          30       30  ...         30         30
# 812          -1          -1          -1       -1  ...         -1         -1
# 813          30          30          30       30  ...         30         30
# 814          30          30          30       30  ...         30         30
# 815          30          30          30       30  ...         30         30
# 816          30          30          30       30  ...         30         30
# 817          -1          -1          -1       -1  ...         -1         -1
# 818          -1          -1          30       30  ...         30         -1
# 819          30          30          30       30  ...         30         30
# 820          -1          -1          -1       30  ...         -1         -1
#
#      500_500_7  500_500_8  500_500_9  500_500_10  500_500_15  500_500_20  \
# 806         30         30         30          30          30          30
# 807         30         30         30          30          30          30
# 808         30         30         30          30          30          30
# 809         30         30         30          30          30          30
# 810         30         30         30          30          30          30
# 811         30         30         30          30          30          30
# 812         -1         -1         -1          -1          -1          -1
# 813         30         30         30          30          30          30
# 814         30         30         30          30          30          30
# 815         30         30         30          30          30          30
# 816         30         30         30          30          30          30
# 817         -1         -1         -1          -1          -1          -1
# 818         -1         -1         -1          30          30          30
# 819         30         30         30          30          30          30
# 820         -1         -1         -1          -1          -1          -1
#
#      500_500_30  label_val
# 806          30         -1
# 807          30         -1
# 808          30         -1
# 809          30         -1
# 810          30         -1
# 811          30         -1
# 812          -1         -1
# 813          30         -1
# 814          30         -1
# 815          30         -1
# 816          30         -1
# 817          -1         -1
# 818          30         -1
# 819          30         -1
# 820          -1         -1
#
# [15 rows x 649 columns]

# %%
# create loss score data frame
col_list = []
score_list = []

for col in combi_result.columns[:-1]:
    # make score
    score = sum(np.abs(np.array(combi_result[col])-np.array(combi_result['label_val'])))
    col_list.append(col)
    score_list.append(score)
    
score_df = pd.DataFrame({'parameter':col_list, 'score':score_list})
score_df.head()
# Out:
#    parameter  score
# 0  50_auto_3    403
# 1  50_auto_5    372
# 2  50_auto_7    341
# 3  50_auto_8    372
# 4  50_auto_9    372

# %%
# score 좋은 것부터 확인
score_df.sort_values(by='score').head()
# Out:
#       parameter  score
# 83      60_10_7    279
# 182    70_100_7    279
# 61    50_300_20    279
# 448   200_10_20    281
# 484  200_200_20    310

# %% [markdown]
# # Valid 결과

# %%
from sklearn.ensemble import IsolationForest

iforest = IsolationForest(n_estimators=70,
                          max_samples='auto',
                          max_features=7,
                          contamination=0.01,
                          random_state=42)
iforest.fit(train2d)
valid_pred = iforest.predict(valid2d)

# %%
import pandas as pd

result = pd.DataFrame(valid_pred, columns=['value'])
result.head()
# Out:
#    value
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
outlier = result[result.value==-1].index
outlier
# Out:
# Int64Index([111, 586, 809, 812, 813, 815, 817, 818, 819, 820], dtype='int64')

# %%
plt.figure(figsize=(10,10))

for i in range(len(outlier)):
    n = np.ceil(np.sqrt(len(outlier)))
    plt.subplot(n,n,i+1)
    plt.imshow(cv2.cvtColor(valid2[outlier[i]], cv2.COLOR_BGR2RGB))
    plt.title(f'outlier {outlier[i]}')
    plt.axis('off')
    
plt.show()
# Out:
# /var/folders/f4/fb3b_sqx3rvc3gfr73v6ck_00000gn/T/ipykernel_6321/20927723.py:5: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(n,n,i+1)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
# valid label
valid_true = np.ones(len(valid2d))
valid_true[-15:] = -1
valid_pred = valid_pred

# %%
print('confusion matrix of valid set:')
print(confusion_matrix(valid_true, valid_pred))
# Out:
# confusion matrix of valid set:
# [[  8   7]
#  [  2 804]]

# %%
# valid score
valid_report_result = classification_report(valid_true,
                                            valid_pred,
                                            target_names=['anomaly', 'normal'])
print(valid_report_result)
# Out:
#               precision    recall  f1-score   support
#
#      anomaly       0.80      0.53      0.64        15
#       normal       0.99      1.00      0.99       806
#
#     accuracy                           0.99       821
#    macro avg       0.90      0.77      0.82       821
# weighted avg       0.99      0.99      0.99       821

# %% [markdown]
# 7개의 이상치 중에서 5개만을 찾았다. ㅠ

# %% [markdown]
# # TEST 결과

# %%
from sklearn.ensemble import IsolationForest

iforest = IsolationForest(n_estimators=50,
                          max_samples='auto',
                          max_features=7,
                          contamination=0.01,
                          random_state=42)
iforest.fit(train2d)
test_pred = iforest.predict(test2d)

# %%
import pandas as pd

result = pd.DataFrame(test_pred, columns=['value'])
result.head()
# Out:
#    value
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
outlier = result[result.value==-1].index
outlier
# Out:
# Int64Index([538, 540, 543, 544, 546, 548, 549, 550], dtype='int64')

# %%
plt.figure(figsize=(10,10))

for i in range(len(outlier)):
    n = np.ceil(np.sqrt(len(outlier)))
    plt.subplot(n,n,i+1)
    plt.imshow(cv2.cvtColor(test2[outlier[i]], cv2.COLOR_BGR2RGB))
    plt.title(f'outlier {outlier[i]}')
    plt.axis('off')
    
plt.show()
# Out:
# /var/folders/f4/fb3b_sqx3rvc3gfr73v6ck_00000gn/T/ipykernel_6321/4268629402.py:5: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(n,n,i+1)

# %% [markdown]
# # SUMMARY

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
# test label
test_true = np.ones(len(test2d))
test_true[-15:] = -1
test_pred = test_pred

# %%
print('confusion matrix of test set:')
print(confusion_matrix(test_true, test_pred))
# Out:
# confusion matrix of test set:
# [[  8   7]
#  [  0 537]]

# %%
# test score
test_report_result = classification_report(test_true,
                                           test_pred,
                                           target_names=['anomaly', 'normal'])
print(test_report_result)
# Out:
#               precision    recall  f1-score   support
#
#      anomaly       1.00      0.53      0.70        15
#       normal       0.99      1.00      0.99       537
#
#     accuracy                           0.99       552
#    macro avg       0.99      0.77      0.84       552
# weighted avg       0.99      0.99      0.99       552
