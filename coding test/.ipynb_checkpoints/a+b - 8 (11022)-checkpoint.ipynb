# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = int(input())
for i in range(T):
    i += 1
    a ,b = map(int, input().split())
    c = a + b
    print("Case #%d: %d + %d = %d" %(i, a, b, c))
# Out:
# 5
# 1 1
# Case #1: 1 + 1 = 2
# 2 3
# Case #2: 2 + 3 = 5
# 3 4
# Case #3: 3 + 4 = 7
# 9 8
# Case #4: 9 + 8 = 17
# 5 2
# Case #5: 5 + 2 = 7
