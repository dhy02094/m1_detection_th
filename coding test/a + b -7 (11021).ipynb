# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = int(input())
for i in range(T):
    i = i + 1 
    a, b = map(int, input().split())
    c = a+b
    print("Case #%d:"%i, c)
# Out:
# 5
# 1 1
# Case #1: 2
# 2 3
# Case #2: 5
# 3 4
# Case #3: 7
# 9 8
# Case #4: 17
# 5 2
# Case #5: 7
