# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# ㅋㅋㅋ 이거 모지? 우연히 알게됨. 이유찾기
n, m = map(int, input().split())
size=n*m
print(size-1)
# Out:
# 2 2
# 3

# %% [markdown]
# 가로가 n 이라고 하면 1로 만드려면 n-1 번 자른다
# 세로가 m 이면 m-1 번 자른다.
#
# 가로 먼저 자르거나 세로로 먼저 자르던지 잘라 나온 개수만큼 곱해줘야한다.
# => n-1 + (m-1)*n = nm-1
