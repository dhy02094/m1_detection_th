# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a = int(input())
b = input() # 하나하나씩 떼기위해서.
axb2 = a * int(b[2])
axb1 = a * int(b[1])
axb0 = a * int(b[0])
axb = a * int(b)
print(axb2, axb1, axb0, axb, sep='\n')
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720

# %% [markdown]
# 아마 난 저번에 b/10 , b/100 - b/10, b - b/100 이런식인거 같은데 위에 풀이로 익히자

# %%
# Out:
# 380
