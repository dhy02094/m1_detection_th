# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a, b = map(int, input().split())
print(a+b)
print(a-b)
print(a*b)
print(int(a/b)) # 아 이런것도못함..?
print(a%b)
# Out:
# 7 3
# 10
# 4
# 21
# 2
# 1
